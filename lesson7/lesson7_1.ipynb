# %%
#建立list
cities = ['台北','台中','高雄']
print(cities)
print(cities[0])
print(cities[1])
print(cities[2])
# Out:
# ['台北', '台中', '高雄']
# 台北
# 台中
# 高雄

# %%
greetings = ['H','e','l','l','o',' ','W','o','r','l','d']

# %%
# 建立list的實體
greetings = list("Hello World!")
print(type(greetings))
print(greetings)
print(greetings[0])
print(greetings[11])
# Out:
# <class 'list'>
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd', '!']
# H
# !
