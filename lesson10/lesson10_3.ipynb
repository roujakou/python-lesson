# %%
class Person:
    def __init__(self):
        self.name = "robert"
        self.age = 25

# %%
p1 = Person()
print(p1.name)
print(p1.age)
# Out:
# robert
# 25

# %%
p2 = Person()
print(p2.name)
print(p2.age)
# Out:
# robert
# 25
