# %%
#數字遊戲
import random
min = 1
max = 100
count = 0
target = random.randint(min,max)
print("========猜數字遊戲========:\n")

while(True):
    count += 1
    keyin = int(input(f"猜數字範圍{min}~{max}:"))
    if keyin >= min and keyin <= max:
        if keyin == target:
            print(f"bingo,{keyin}為正確答案")
            print(f"你猜了{count}次")
            break
        elif keyin > target:
            print("在小一點")
            max = keyin - 1
        elif keyin < target:
            print("再大一點")
            min = keyin + 1

        print(f"你已經猜了{count}次")
    else:
        print("不在範圍內")
        break

    print("遊戲結束")
# Out:
# ========猜數字遊戲========:
#
# 再大一點
# 你已經猜了1次
# 遊戲結束
# 再大一點
# 你已經猜了2次
# 遊戲結束
# 再大一點
# 你已經猜了3次
# 遊戲結束
# 再大一點
# 你已經猜了4次
# 遊戲結束
# 再大一點
# 你已經猜了5次
# 遊戲結束
# 在小一點
# 你已經猜了6次
# 遊戲結束
# bingo,91為正確答案
# 你猜了7次

# %%
#數字遊戲
import random
while(True):
    min = 1
    max = 100
    count = 0
    target = random.randint(min,max)
    print("========猜數字遊戲========:\n")

    while(True):
        count += 1
        keyin = int(input(f"猜數字範圍{min}~{max}:"))
        if keyin >= min and keyin <= max:
            if keyin == target:
                print(f"bingo,{keyin}為正確答案")
                print(f"你猜了{count}次")
                break
            elif keyin > target:
                print("在小一點")
                max = keyin - 1
            elif keyin < target:
                print("再大一點")
                min = keyin + 1

            print(f"你已經猜了{count}次")
        else:
            print("不在範圍內")
            break
    play_again = input("請問還要繼續嗎(y,n)")
    if play_again == 'n':
        break

print("遊戲結束")
# Out:
# ========猜數字遊戲========:
#
# 在小一點
# 你已經猜了1次
# 在小一點
# 你已經猜了2次
# 在小一點
# 你已經猜了3次
# 在小一點
# 你已經猜了4次
# 再大一點
# 你已經猜了5次
# 不在範圍內
# ========猜數字遊戲========:
#
# 再大一點
# 你已經猜了1次
# 不在範圍內
# ========猜數字遊戲========:
#
# 在小一點
# 你已經猜了1次
# 再大一點
# 你已經猜了2次
# 不在範圍內
# ========猜數字遊戲========:
#
# 再大一點
# 你已經猜了1次
# 在小一點
# 你已經猜了2次
# 在小一點
# 你已經猜了3次
# 不在範圍內
# ========猜數字遊戲========:
#
# 再大一點
# 你已經猜了1次
# 在小一點
# 你已經猜了2次
# 在小一點
# 你已經猜了3次
# 在小一點
# 你已經猜了4次
# 再大一點
# 你已經猜了5次
# 再大一點
# 你已經猜了6次
# 在小一點
# 你已經猜了7次
# bingo,30為正確答案
# 你猜了8次
# 遊戲結束

# %%
#數字遊戲
import random
def play_game():  #自訂function
    min = 1
    max = 100
    count = 0
    target = random.randint(min,max)
    print("========猜數字遊戲========:\n")

    while(True):
        count += 1
        keyin = int(input(f"猜數字範圍{min}~{max}:"))
        if keyin >= min and keyin <= max:
            if keyin == target:
                print(f"bingo,{keyin}為正確答案")
                print(f"你猜了{count}次")
                break
            elif keyin > target:
                print("在小一點")
                max = keyin - 1
            elif keyin < target:
                print("再大一點")
                min = keyin + 1

            print(f"你已經猜了{count}次")
        else:
            print("不在範圍內")
            break
while(True):
    play_game()    
    play_again = input("請問還要繼續嗎(y,n)")
    if play_again == 'n':
        break

print("遊戲結束")
# Out:
# ========猜數字遊戲========:
#
# 再大一點
# 你已經猜了1次
# 再大一點
# 你已經猜了2次
# 再大一點
# 你已經猜了3次
# 再大一點
# 你已經猜了4次
# 再大一點
# 你已經猜了5次
# 再大一點
# 你已經猜了6次
# 再大一點
# 你已經猜了7次
# 再大一點
# 你已經猜了8次
# 在小一點
# 你已經猜了9次
# bingo,92為正確答案
# 你猜了10次
# 遊戲結束
